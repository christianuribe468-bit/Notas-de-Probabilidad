# %% [markdown]
# <a href="https://colab.research.google.com/github/christianuribe468-bit/Notas-de-Probabilidad/blob/main/practica.1_probabilidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJEMPLO DETERMINISTA

# %%
import sympy

def area(radio):
    return sympy.pi * (radio ** 2)

# %%
area (10)

# %% [markdown]
# Ejemlo numerico

# %%
def area(radio):
    return 3.1516 * (radio ** 2)

# %%
area_numerico(10)

# %% [markdown]
# LANZAMIENTO DE MONEDA "EJEMPLO ALEATORIO"

# %%
import random

Dado_lados = ["1", "2", "3", "4", "5", "6"]

def lanzar_dado():
    return random.choice(Dado_lados)

lanzar_dado()
# Out:
# '3'
